# %%
import sys
import os
import base64

w = base64.b64decode(("d2VidWk=").encode('ascii')).decode('ascii')
sdw = base64.b64decode(("c3RhYmxlLWRpZmZ1c2lvbi13ZWJ1aQ==").encode('ascii')).decode('ascii')

# %%
# %cd /content

# %env TF_CPP_MIN_LOG_LEVEL=1

# !apt -y update -qq
# !wget http://launchpadlibrarian.net/367274644/libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/google-perftools_2.5-2.2ubuntu3_all.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb
# !apt install -qq libunwind8-dev
# !dpkg -i *.deb
# %env LD_PRELOAD=libtcmalloc.so
# !rm *.deb

# !apt -y install -qq aria2 libcairo2-dev pkg-config python3-dev
# !pip install -q torch==1.13.1+cu116 torchvision==0.14.1+cu116 torchaudio==0.13.1 torchtext==0.14.1 torchdata==0.5.1 --extra-index-url https://download.pytorch.org/whl/cu116 -U
# !pip install -q xformers==0.0.16 triton==2.0.0 -U

# !git clone -b v2.1 https://github.com/camenduru/$sdw
# !git clone https://huggingface.co/embed/negative /content/$sdw/embeddings/negative
# !git clone https://huggingface.co/embed/lora /content/$sdw/models/Lora/positive
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/embed/upscale/resolve/main/4x-UltraSharp.pth -d /content/$sdw/models/ESRGAN -o 4x-UltraSharp.pth
# !wget https://raw.githubusercontent.com/camenduru/$sdw-scripts/main/run_n_times.py -O /content/$sdw/scripts/run_n_times.py
# !git clone https://github.com/deforum-art/deforum-for-automatic1111-$w /content/$sdw/extensions/deforum-for-automatic1111-$w
# !git -C /content/$sdw/extensions/deforum-for-automatic1111-$w fetch
# !git -C /content/$sdw/extensions/deforum-for-automatic1111-$w checkout 0056c493e0dd44d2524175564f8fb91e40c94c59
# !git clone https://github.com/camenduru/$sdw-images-browser /content/$sdw/extensions/$sdw-images-browser
# !git clone https://github.com/camenduru/$sdw-huggingface /content/$sdw/extensions/$sdw-huggingface
# !git clone https://github.com/camenduru/sd-civitai-browser /content/$sdw/extensions/sd-civitai-browser
# !git clone https://github.com/kohya-ss/sd-$w-additional-networks /content/$sdw/extensions/sd-$w-additional-networks
# !git clone https://github.com/Mikubill/sd-$w-controlnet /content/$sdw/extensions/sd-$w-controlnet
# !git clone https://github.com/fkunn1326/openpose-editor /content/$sdw/extensions/openpose-editor
# !git clone https://github.com/jexom/sd-$w-depth-lib /content/$sdw/extensions/sd-$w-depth-lib
# !git clone https://github.com/hnmr293/posex /content/$sdw/extensions/posex
# !git clone https://github.com/nonnonstop/sd-$w-3d-open-pose-editor /content/$sdw/extensions/sd-$w-3d-open-pose-editor
# !git clone https://github.com/camenduru/sd-$w-tunnels /content/$sdw/extensions/sd-$w-tunnels
# !git clone https://github.com/etherealxx/batchlinks-$w /content/$sdw/extensions/batchlinks-$w
# !git clone https://github.com/camenduru/$sdw-catppuccin /content/$sdw/extensions/$sdw-catppuccin
# !git clone https://github.com/camenduru/a1111-sd-$w-locon /content/$sdw/extensions/a1111-sd-$w-locon
# !git clone https://github.com/AUTOMATIC1111/$sdw-rembg /content/$sdw/extensions/$sdw-rembg
# !git clone https://github.com/ashen-sensored/$sdw-two-shot /content/$sdw/extensions/$sdw-two-shot
# !git clone https://github.com/camenduru/sd_$w_stealth_pnginfo /content/$sdw/extensions/sd_$w_stealth_pnginfo
# !git clone https://github.com/thomasasfk/sd-$w-aspect-ratio-helper /content/$sdw/extensions/sd-$w-aspect-ratio-helper
# !git clone https://github.com/tjm35/asymmetric-tiling-sd-$w /content/$sdw/extensions/asymmetric-tiling-sd-$w
# %cd /content/$sdw
# !git reset --hard
# !git -C /content/$sdw/repositories/stable-diffusion-stability-ai reset --hard

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11e_sd15_ip2p_fp16.safetensors -d /content/$sdw/extensions/sd-$w-controlnet/models -o control_v11e_sd15_ip2p_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11e_sd15_shuffle_fp16.safetensors -d /content/$sdw/extensions/sd-$w-controlnet/models -o control_v11e_sd15_shuffle_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_canny_fp16.safetensors -d /content/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_canny_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11f1p_sd15_depth_fp16.safetensors -d /content/$sdw/extensions/sd-$w-controlnet/models -o control_v11f1p_sd15_depth_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_inpaint_fp16.safetensors -d /content/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_inpaint_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_lineart_fp16.safetensors -d /content/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_lineart_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_mlsd_fp16.safetensors -d /content/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_mlsd_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_normalbae_fp16.safetensors -d /content/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_normalbae_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_openpose_fp16.safetensors -d /content/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_openpose_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_scribble_fp16.safetensors -d /content/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_scribble_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_seg_fp16.safetensors -d /content/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_seg_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_softedge_fp16.safetensors -d /content/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_softedge_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15s2_lineart_anime_fp16.safetensors -d /content/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15s2_lineart_anime_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11f1e_sd15_tile_fp16.safetensors -d /content/$sdw/extensions/sd-$w-controlnet/models -o control_v11f1e_sd15_tile_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11e_sd15_ip2p_fp16.yaml -d /content/$sdw/extensions/sd-$w-controlnet/models -o control_v11e_sd15_ip2p_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11e_sd15_shuffle_fp16.yaml -d /content/$sdw/extensions/sd-$w-controlnet/models -o control_v11e_sd15_shuffle_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_canny_fp16.yaml -d /content/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_canny_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11f1p_sd15_depth_fp16.yaml -d /content/$sdw/extensions/sd-$w-controlnet/models -o control_v11f1p_sd15_depth_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_inpaint_fp16.yaml -d /content/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_inpaint_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_lineart_fp16.yaml -d /content/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_lineart_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_mlsd_fp16.yaml -d /content/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_mlsd_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_normalbae_fp16.yaml -d /content/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_normalbae_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_openpose_fp16.yaml -d /content/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_openpose_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_scribble_fp16.yaml -d /content/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_scribble_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_seg_fp16.yaml -d /content/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_seg_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_softedge_fp16.yaml -d /content/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_softedge_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15s2_lineart_anime_fp16.yaml -d /content/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15s2_lineart_anime_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11f1e_sd15_tile_fp16.yaml -d /content/$sdw/extensions/sd-$w-controlnet/models -o control_v11f1e_sd15_tile_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_style_sd14v1.pth -d /content/$sdw/extensions/sd-$w-controlnet/models -o t2iadapter_style_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_sketch_sd14v1.pth -d /content/$sdw/extensions/sd-$w-controlnet/models -o t2iadapter_sketch_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_seg_sd14v1.pth -d /content/$sdw/extensions/sd-$w-controlnet/models -o t2iadapter_seg_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_openpose_sd14v1.pth -d /content/$sdw/extensions/sd-$w-controlnet/models -o t2iadapter_openpose_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_keypose_sd14v1.pth -d /content/$sdw/extensions/sd-$w-controlnet/models -o t2iadapter_keypose_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_depth_sd14v1.pth -d /content/$sdw/extensions/sd-$w-controlnet/models -o t2iadapter_depth_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_color_sd14v1.pth -d /content/$sdw/extensions/sd-$w-controlnet/models -o t2iadapter_color_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_canny_sd14v1.pth -d /content/$sdw/extensions/sd-$w-controlnet/models -o t2iadapter_canny_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_canny_sd15v2.pth -d /content/$sdw/extensions/sd-$w-controlnet/models -o t2iadapter_canny_sd15v2.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_depth_sd15v2.pth -d /content/$sdw/extensions/sd-$w-controlnet/models -o t2iadapter_depth_sd15v2.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_sketch_sd15v2.pth -d /content/$sdw/extensions/sd-$w-controlnet/models -o t2iadapter_sketch_sd15v2.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_zoedepth_sd15v1.pth -d /content/$sdw/extensions/sd-$w-controlnet/models -o t2iadapter_zoedepth_sd15v1.pth

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/sd15/resolve/main/v1-5-pruned-emaonly.ckpt -d /content/$sdw/models/Stable-diffusion -o v1-5-pruned-emaonly.ckpt

# !sed -i -e '''/    prepare_environment()/a\    os.system\(f\"""sed -i -e ''\"s/dict()))/dict())).cuda()/g\"'' /content/$sdw/repositories/stable-diffusion-stability-ai/ldm/util.py""")''' /content/$sdw/launch.py
# !sed -i -e 's/\"sd_model_checkpoint\"\,/\"sd_model_checkpoint\,sd_vae\,CLIP_stop_at_last_layers\"\,/g' /content/$sdw/modules/shared.py

# !python launch.py --listen --xformers --enable-insecure-extension-access --theme dark --gradio-queue --multiple
